# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.sample(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3773  8260-NGFNY  Female              0      No         No       1
# 6953  1564-NTYXF  Female              1      No         No      13
# 6279  4012-ZTHBR  Female              0     Yes        Yes      21
# 7031  3605-JISKB    Male              1     Yes         No      55
# 524   8397-MVTAZ    Male              0     Yes         No      34
# 4037  0603-TPMIB  Female              0     Yes        Yes      59
# 1608  2387-KDZQY    Male              0      No         No      17
# 737   2521-NPUZR    Male              0     Yes         No      70
# 4918  6582-PLFUU    Male              0     Yes        Yes      51
# 6023  4698-KVLLG  Female              1      No         No      51
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 3773           No  No phone service             DSL                   No  ...
# ...

# %%
df.drop('customerID', axis=1)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
string_cols = df.select_dtypes(include = ['string']).columns
df[string_cols]  = df[string_cols].astype('object')
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df['TotalCharges'].isna()]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %% [markdown]
# Observations:
# we found out that 11 customers have total charges = 0
# upon investigation we see that these customers have monthlycharges assigned to them and the reason for total charges to be 0 is because they might have not gotten the first bill yet

# %%
df['PaymentMethod'].unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
df['Churn'][df['Churn'] == 'Yes'].shape[0]/df['Churn'].shape[0]
sns.countplot(x=df['Churn'])
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %% [markdown]
# Nearly 26% of the customers have churned this is a major business problem as gaining new customers is more costlier than retaining old ones

# %%
sns.boxplot(x=df['Churn'], y=df['tenure'])
# Out:
# <Axes: xlabel='Churn', ylabel='tenure'>

# %% [markdown]
# Observations:
# Median for non-churn customer is higher in tenure
# There is an obvious overlap so the tenure column but the seperation of the churn and non churn customers is much cleaner than the other neumerical columns this suggest that the tenure column may be a strong predictor or churn
# Majority of the churn customers have tenure < 30 with a median at around 10 with some outliers at around 70
# Customers with shorter tenure are considerably more likely to churn than long-term customers. This indicates that the first few months after joining are the most critical period for customer retention.

# %%
df.groupby("Churn")["tenure"].describe()
# Out:
#         count       mean        std  min   25%   50%   75%   max
# Churn
# No     5174.0  37.569965  24.113777  0.0  15.0  38.0  61.0  72.0
# Yes    1869.0  17.979133  19.531123  1.0   2.0  10.0  29.0  72.0

# %%
sns.boxplot(x=df['Churn'], y=df['MonthlyCharges'])
# Out:
# <Axes: xlabel='Churn', ylabel='MonthlyCharges'>

# %% [markdown]
# Observations:
# Although there is noticeable overlap between the two groups, churned customers exhibit a higher median monthly charge, indicating that MonthlyCharges is likely to be an informative feature for predicting churn
# Median for non churn customers is lesser than that of churn customers
# There is no obvious outliers
# Customers who churn tend to have higher monthly charges than customers who stay. This suggests that higher monthly charges are associated with an increased likelihood of churn

# %%
df.groupby("Churn")["MonthlyCharges"].describe()
# Out:
#         count       mean        std    min    25%     50%   75%     max
# Churn
# No     5174.0  61.265124  31.092648  18.25  25.10  64.425  88.4  118.75
# Yes    1869.0  74.441332  24.666053  18.85  56.15  79.650  94.2  118.35

# %%
sns.boxplot(x=df['Churn'], y=df['TotalCharges'])
# Out:
# <Axes: xlabel='Churn', ylabel='TotalCharges'>

# %% [markdown]
# Observations:
# At first we might think that why are customers with lower total charges churning but that is explained by the monthly charge and tenure feature
# Customers that have a lower tenure tends to churn and because of that the total charges are low for the churning customer
# total charge is overlapping in churn and non churn customer

# %%
df.groupby("Churn")["TotalCharges"].describe()
# Out:
#         count         mean          std    min      25%      50%       75%  \
# Churn
# No     5163.0  2555.344141  2329.456984  18.80  577.825  1683.60  4264.125
# Yes    1869.0  1531.796094  1890.822994  18.85  134.500   703.55  2331.300
#
#            max
# Churn
# No     8672.45
# Yes    8684.80

# %% [markdown]
# Some of the churned customer had a really high total charges but that can be because they had multiple services or costlier plans

# %%
sns.histplot(df['tenure'], kde=True)
# Out:
# <Axes: xlabel='tenure', ylabel='Count'>

# %% [markdown]
# the tenure feature appears bimodal with large number of either leave the company within few months or very loyal customers staying with the company for months
# there is a relatively low number of customer in the middle

# %%
df['tenure'].median()
# Out:
# np.float64(29.0)

# %%
df['tenure'].describe()
# Out:
# count    7043.000000
# mean       32.371149
# std        24.559481
# min         0.000000
# 25%         9.000000
# 50%        29.000000
# 75%        55.000000
# max        72.000000
# Name: tenure, dtype: float64

# %%
df.groupby("Churn")["tenure"].describe()
# Out:
#         count       mean        std  min   25%   50%   75%   max
# Churn
# No     5174.0  37.569965  24.113777  0.0  15.0  38.0  61.0  72.0
# Yes    1869.0  17.979133  19.531123  1.0   2.0  10.0  29.0  72.0

# %% [markdown]
# Observations:
# the 25% for the churning customers is 2 months meaning that 1 in every 4 customer that churns are likely to leave in the first couple of months
# the 50% for the churning customer is 10 months meaning that the initial few months are very important to retain the customers
# there are some churning customer with very high tenure that shifted the mean as median is 10 and mean is 17

# %%
sns.histplot(df['MonthlyCharges'], kde=True)
# Out:
# <Axes: xlabel='MonthlyCharges', ylabel='Count'>

# %%
df['MonthlyCharges'].median()
# Out:
# np.float64(70.35)

# %%
df['MonthlyCharges'].describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: MonthlyCharges, dtype: float64

# %%
df.groupby("Churn")["MonthlyCharges"].describe()
# Out:
#         count       mean        std    min    25%     50%   75%     max
# Churn
# No     5174.0  61.265124  31.092648  18.25  25.10  64.425  88.4  118.75
# Yes    1869.0  74.441332  24.666053  18.85  56.15  79.650  94.2  118.35

# %% [markdown]
# Observations:
# 25% of the churned customers pay less than 56 units whereas 25% of the retained customer pays less than 25 units
# we can also see that the median for churned customer is 15 units higher than the retained customer
# both of these statistical observations indicate that higher price is associated with increased likelyhood to churn
# the distribution appears to be bimodal with a lot of customers having very little monthly charges and a lot having high monthly charge

# %%
sns.histplot(df['TotalCharges'], kde=True)
# Out:
# <Axes: xlabel='TotalCharges', ylabel='Count'>

# %%
df['TotalCharges'].describe()
# Out:
# count    7032.000000
# mean     2283.300441
# std      2266.771362
# min        18.800000
# 25%       401.450000
# 50%      1397.475000
# 75%      3794.737500
# max      8684.800000
# Name: TotalCharges, dtype: float64

# %%
df.groupby('Churn')['TotalCharges'].describe()
# Out:
#         count         mean          std    min      25%      50%       75%  \
# Churn
# No     5163.0  2555.344141  2329.456984  18.80  577.825  1683.60  4264.125
# Yes    1869.0  1531.796094  1890.822994  18.85  134.500   703.55  2331.300
#
#            max
# Churn
# No     8672.45
# Yes    8684.80

# %% [markdown]
# Observations:
# some customer have really high total charges that is shifting the mean causing a right skew in the data these may represent the loyal customers with higher tenure periods or customers with premium services
# most of the customers have a really low total charge these can be the customers with low tenure that churned
# the total charges in all the quantile are low for the churned customers this can be a consequence of lower tenure periods rather than an indication that lower total charges reduces churn

# %%
df = df.drop('customerID', axis=1)
catcols = df.select_dtypes(include=['object']).columns
catcols
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Churn'],
#       dtype='str')

# %%
sns.countplot(x=df['Contract'], hue =df['Churn'])
# Out:
# <Axes: xlabel='Contract', ylabel='count'>

# %%
pd.crosstab(
    df['Contract'],
    df['Churn'],
    normalize = "index"
)*100
# Out:
# Churn                  No        Yes
# Contract
# Month-to-month  57.290323  42.709677
# One year        88.730482  11.269518
# Two year        97.168142   2.831858

# %% [markdown]
# Observations and interpretation:
# it seems that the longer contracts have significantly less churn rates this is very logical given the information about the tenure feature
# The initial few months are very important as the customers who churn are more likely to leave in that time
# people with longer tenure periods are less likely to churn which aligns with out previous numerical analysis
# a month to month contract type has a higher churn rates that can be explained by the flexibility to leave the services after few months in this type of contract where as a year to year or a two year contract allows the customer to stay for a long time leading to lower tenure period
#
# Business recommendation:
# the company should consider offering attractive deals and loyalty rewards to transition the customers from month to month contracts to a longer contractual period which can help in customer retention
#
# Take away:
# contract type appears to be a very strong predictor or churn and should be considered important

# %%
sns.countplot(x=df['InternetService'], hue =df['Churn'])
# Out:
# <Axes: xlabel='InternetService', ylabel='count'>

# %%
pd.crosstab(
    df['InternetService'],
    df['Churn'],
    normalize="index"
)* 100
# Out:
# Churn                   No        Yes
# InternetService
# DSL              81.040892  18.959108
# Fiber optic      58.107235  41.892765
# No               92.595020   7.404980

# %% [markdown]
# Observation:
# the fiber optic type of internet services have a significant churn rate
# we should investigate further to know why is that a case maybe it is more expensive?
#
# Root cause assumption:
# Higher monthly charges
# a month to month contract
# no techsupport
# no online support
# higher tenure periods

# %%
sns.boxplot(x=df['InternetService'], y=df['MonthlyCharges'])
# Out:
# <Axes: xlabel='InternetService', ylabel='MonthlyCharges'>

# %% [markdown]
# It seems that a fiber optic connection is more expensive than a DSL which can explain the higher churn rates associated by the previous numerical analysis that customers with higher monthly charges are more likely to churn
# both the box plot have a clear separation
#
# some more investigation can be done
# we can check if the fiber optic connection customer are on a month to month basis

# %%
sns.countplot(x=df['InternetService'], hue =df['Contract'])
# Out:
# <Axes: xlabel='InternetService', ylabel='count'>

# %%
pd.crosstab(
    df['InternetService'],
    df['Contract'],
    normalize="index"
)* 100
# Out:
# Contract         Month-to-month   One year   Two year
# InternetService
# DSL                   50.516316  23.543990  25.939694
# Fiber optic           68.733850  17.409561  13.856589
# No                    34.338139  23.853211  41.808650

# %% [markdown]
# 68% of the fiber optic connection are on a month to month basis which together with the high monthly charges partly explain the higher churn rates in this type of connection
#
# the second highest churn rates are of DSL which is 18%, this lower churn rate despite of a 50% of the connection being in a month to month contract can be explained by a significantly lower monthly charges

# %%
pd.crosstab(
    [df["Contract"], df["InternetService"]],
    df["Churn"],
    normalize="index"
) * 100
# Out:
# Churn                                  No        Yes
# Contract       InternetService
# Month-to-month DSL              67.784137  32.215863
#                Fiber optic      45.394737  54.605263
#                No               81.106870  18.893130
# One year       DSL              90.701754   9.298246
#                Fiber optic      80.705009  19.294991
#                No               97.527473   2.472527
# Two year       DSL              98.089172   1.910828
#                Fiber optic      92.773893   7.226107
#                No               99.216301   0.783699

# %% [markdown]
# In this crosstab we can see that even with a differnet contract type the fiber optic internet service have a higher churn rate than others meaning that the relationship that fiber optic connection have higher churn rate because most of it is on monthly contract is only partially explaination and it doesn't totally depend on the contract type

# %%
sns.countplot(x=df['InternetService'], hue =df['TechSupport'])
# Out:
# <Axes: xlabel='InternetService', ylabel='count'>

# %%
pd.crosstab(
    df['InternetService'],
    df['TechSupport'],
    normalize="index"
)* 100
# Out:
# TechSupport             No  No internet service        Yes
# InternetService
# DSL              51.342420                  0.0  48.657580
# Fiber optic      72.028424                  0.0  27.971576
# No                0.000000                100.0   0.000000

# %% [markdown]
# only 27% of the fiber optic connection plans include tech support which in case of an issue can leave the customer frustrated an might also explain the higher churn rate

# %%
sns.countplot(x=df['InternetService'], hue =df['OnlineSecurity'])
# Out:
# <Axes: xlabel='InternetService', ylabel='count'>

# %%
pd.crosstab(
    df['InternetService'],
    df['OnlineSecurity'],
    normalize="index"
)* 100
# Out:
# OnlineSecurity          No  No internet service        Yes
# InternetService
# DSL              51.259810                  0.0  48.740190
# Fiber optic      72.900517                  0.0  27.099483
# No                0.000000                100.0   0.000000

# %% [markdown]
# 27% of fiber optic connection plans does not provide online security which can explain why the customers are leaving
# included online security may help in customer retention

# %%
sns.countplot(x=df['InternetService'], hue =df['OnlineBackup'])
# Out:
# <Axes: xlabel='InternetService', ylabel='count'>

# %%
pd.crosstab(
    df['InternetService'],
    df['OnlineBackup'],
    normalize="index"
)* 100
# Out:
# OnlineBackup            No  No internet service        Yes
# InternetService
# DSL              55.142503                  0.0  44.857497
# Fiber optic      56.621447                  0.0  43.378553
# No                0.000000                100.0   0.000000

# %%
sns.boxplot(x=df['InternetService'], y =df['tenure'])
# Out:
# <Axes: xlabel='InternetService', ylabel='tenure'>

# %% [markdown]
# Tenure for both DSL and Fiber optic seems to have similar median and the boxplot for both the connection seems to have a significant overlap
# so the the assumption that fiber optic connection can be the new customer seems wrong

# %%
sns.countplot(x=df['PaymentMethod'], hue=df["Churn"])
# Out:
# <Axes: xlabel='PaymentMethod', ylabel='count'>

# %%
pd.crosstab(
    df['PaymentMethod'],
    df['Churn'],
    normalize="index"
)* 100
# Out:
# Churn                             No        Yes
# PaymentMethod
# Bank transfer (automatic)  83.290155  16.709845
# Credit card (automatic)    84.756899  15.243101
# Electronic check           54.714588  45.285412
# Mailed check               80.893300  19.106700

# %% [markdown]
# Observation:
# the electronic check payment method seems to be the category with the highest churn rate
#
# Root cause assumptions:
# 1. month to month contract
# 2. no paperless billing which might cause a missed email bill causing a churn

# %%
sns.countplot(x=df['PaymentMethod'], hue=df["Contract"])
# Out:
# <Axes: xlabel='PaymentMethod', ylabel='count'>

# %% [markdown]
# Our first assumptions seems valid, most of the electronic check are for a month to month contract which may partially explain the higher churn rates

# %%
sns.countplot(x=df['PaperlessBilling'], hue=df["Churn"])
# Out:
# <Axes: xlabel='PaperlessBilling', ylabel='count'>

# %%
pd.crosstab(
    df['PaperlessBilling'],
    df['Churn'],
    normalize="index"
)* 100
# Out:
# Churn                    No        Yes
# PaperlessBilling
# No                83.669916  16.330084
# Yes               66.434908  33.565092

# %% [markdown]
# 33% of the customer with paperless billing churned this can be a useful information in our second assumption for electronic check

# %%
sns.countplot(x=df['PaymentMethod'], hue=df["PaperlessBilling"])
# Out:
# <Axes: xlabel='PaymentMethod', ylabel='count'>

# %% [markdown]
# Our second assumptions also seems true, as there are a many electronic checks with paperless billing enabled and 33% of customer with paperless billing churns

# %%
pd.crosstab(
    [df["PaymentMethod"], df["PaperlessBilling"]],
    df["Churn"],
    normalize="index"
) * 100
# Out:
# Churn                                              No        Yes
# PaymentMethod             PaperlessBilling
# Bank transfer (automatic) No                88.973966  11.026034
#                           Yes               79.124579  20.875421
# Credit card (automatic)   No                90.000000  10.000000
#                           Yes               80.952381  19.047619
# Electronic check          No                67.255217  32.744783
#                           Yes               50.229621  49.770379
# Mailed check              No                86.506276  13.493724
#                           Yes               72.713415  27.286585

# %% [markdown]
# customers with electronic check seems to have a higher churn rate in all the 4 payment categories

# %%
pd.crosstab(
    [df["Contract"], df["PaymentMethod"]],
    df["Churn"],
    normalize="index"
) * 100
# Out:
# Churn                                            No        Yes
# Contract       PaymentMethod
# Month-to-month Bank transfer (automatic)  65.874363  34.125637
#                Credit card (automatic)    67.219153  32.780847
#                Electronic check           46.270270  53.729730
#                Mailed check               68.421053  31.578947
# One year       Bank transfer (automatic)  90.281330   9.718670
#                Credit card (automatic)    89.698492  10.301508
#                Electronic check           81.556196  18.443804
#                Mailed check               93.175074   6.824926
# Two year       Bank transfer (automatic)  96.631206   3.368794
#                Credit card (automatic)    97.762478   2.237522
#                Electronic check           92.261905   7.738095
#                Mailed check               99.214660   0.785340

# %% [markdown]
# contract type alone doesn't explain churn as the churn rates are more for electronic check customer in the similar contract type

# %%
sns.countplot(x=df['TechSupport'], hue=df["Churn"])
# Out:
# <Axes: xlabel='TechSupport', ylabel='count'>

# %%
pd.crosstab(
    df["TechSupport"],
    df["Churn"],
    normalize="index"
) * 100
# Out:
# Churn                       No        Yes
# TechSupport
# No                   58.364526  41.635474
# No internet service  92.595020   7.404980
# Yes                  84.833659  15.166341

# %% [markdown]
# Plans with no tech support seems to have a higher churn rate this seems logical as a frustrated customer may leave if there is no tech help it seems to partially explain churn

# %%
catcols
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Churn'],
#       dtype='str')

# %%
# tech support done, payment method done, contract type done, internet service done,

# %%
pd.crosstab(
    [df["Contract"],df["TechSupport"]],
    df['Churn'],
    normalize="index"
) * 100
# Out:
# Churn                                      No        Yes
# Contract       TechSupport
# Month-to-month No                   49.626866  50.373134
#                No internet service  81.106870  18.893130
#                Yes                  69.299553  30.700447
# One year       No                   85.278276  14.721724
#                No internet service  97.527473   2.472527
#                Yes                  86.413043  13.586957
# Two year       No                   94.067797   5.932203
#                No internet service  99.216301   0.783699
#                Yes                  96.467722   3.532278

# %% [markdown]
# we can see that even in the month to month contract type having tech support reduces churn by 20 points (30% vs 50%) it may not fully explain churn but it is an important features from the findings

# %%
sns.countplot(x=df['OnlineSecurity'], hue=df['Churn'])
# Out:
# <Axes: xlabel='OnlineSecurity', ylabel='count'>

# %%
pd.crosstab(
    df['OnlineSecurity'],
    df['Churn'],
    normalize='index'
)*100
# Out:
# Churn                       No        Yes
# OnlineSecurity
# No                   58.233276  41.766724
# No internet service  92.595020   7.404980
# Yes                  85.388806  14.611194

# %% [markdown]
# it seems that no 41% of the customers without online security churned we need to investigate further if this is because online security is included in specific plans or if this is strongly associated with churn

# %%
pd.crosstab(
    [df['Contract'],df['OnlineSecurity']],
    df['Churn'],
    normalize='index'
)*100
# Out:
# Churn                                      No        Yes
# Contract       OnlineSecurity
# Month-to-month No                   48.954770  51.045230
#                No internet service  81.106870  18.893130
#                Yes                  70.416667  29.583333
# One year       No                   82.585278  17.414722
#                No internet service  97.527473   2.472527
#                Yes                  89.130435  10.869565
# Two year       No                   93.225806   6.774194
#                No internet service  99.216301   0.783699
#                Yes                  97.054886   2.945114

# %% [markdown]
# from the observation we can see that in the month to month contract having online security can significantly reduce churn by 20 points (30%,50%) similar to tech support this may not fully explain churn but online security is also a strong predictor of churn depending on the contract type

# %%
sns.countplot(x=df['OnlineSecurity'], hue=df['TechSupport'])
# Out:
# <Axes: xlabel='OnlineSecurity', ylabel='count'>

# %% [markdown]
# it also seems that most of the customers with no tech support also do not have online security this could be because both of these services are often bundled together in plans or bought together

# %%
sns.countplot(x=df['Contract'], hue=df['OnlineSecurity'])
# Out:
# <Axes: xlabel='Contract', ylabel='count'>

# %%
sns.countplot(x=df['Contract'], hue=df['TechSupport'])
# Out:
# <Axes: xlabel='Contract', ylabel='count'>

# %% [markdown]
# from the above two graphs it seems that majority of the month to month contracts have no tech support or online security, other contract types such as year to year have more customers with online security and tech support
# though tech support and online security seems to be strongly associated with contract type still the online security and tech support both are strong predictor of churn

# %%
catcols
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Churn'],
#       dtype='str')

# %%
sns.countplot(x=df['OnlineBackup'], hue=df['Churn'])
# Out:
# <Axes: xlabel='OnlineBackup', ylabel='count'>

# %%
pd.crosstab(
    df['OnlineBackup'],
    df['Churn'],
    normalize='index'
)*100
# Out:
# Churn                       No        Yes
# OnlineBackup
# No                   60.071244  39.928756
# No internet service  92.595020   7.404980
# Yes                  78.468506  21.531494

# %% [markdown]
# customers having online backup tends to show lower churn rates from the customer having no online backup in the observation almost a 20 unit difference(39% vs 21%) is seen
# online backup also seems associated with churn
# we need further investigation to see if it is a strong predictor

# %%
pd.crosstab(
    [df['Contract'],df['OnlineBackup']],
    df['Churn'],
    normalize='index'
)*100
# Out:
# Churn                                      No        Yes
# Contract       OnlineBackup
# Month-to-month No                   49.694056  50.305944
#                No internet service  81.106870  18.893130
#                Yes                  61.900282  38.099718
# One year       No                   86.652977  13.347023
#                No internet service  97.527473   2.472527
#                Yes                  85.209003  14.790997
# Two year       No                   94.568690   5.431310
#                No internet service  99.216301   0.783699
#                Yes                  96.505376   3.494624

# %% [markdown]
# from the observation we can see that in the month to month contract having Onlinebackup can reduce churn by 12 points (50%,38%) similar to tech support and online security this may not fully explain churn but online security is also a strong predictor of churn depending on the contract type

# %%
sns.countplot(x=df['OnlineBackup'], hue=df['TechSupport'])
# Out:
# <Axes: xlabel='OnlineBackup', ylabel='count'>

# %%
sns.countplot(x=df['OnlineBackup'], hue=df['OnlineSecurity'])
# Out:
# <Axes: xlabel='OnlineBackup', ylabel='count'>

# %% [markdown]
# it also seems that most of the customers with no tech support and online security also do not have online backup this could be because both of these services are often bundled together in plans or bought together

# %%
sns.countplot(x=df['Contract'], hue=df['OnlineBackup'])
# Out:
# <Axes: xlabel='Contract', ylabel='count'>

# %% [markdown]
# from the above graphs it seems that majority of the month to month contracts have no online backup similar to tech support or online services, other contract types such as year to year have more customers with online backup
# though online backup seems to be associated with contract type still online backup is a descent predictor of churn

# %%
pd.crosstab(
    [df['TechSupport'],df['OnlineBackup']],
    df['Churn'],
    normalize='index'
)*100
# Out:
# Churn                                           No        Yes
# TechSupport         OnlineBackup
# No                  No                   52.231330  47.768670
#                     Yes                  68.911511  31.088489
# No internet service No internet service  92.595020   7.404980
# Yes                 No                   79.372197  20.627803
#                     Yes                  89.062500  10.937500

# %%
pd.crosstab(
    [df['OnlineSecurity'],df['OnlineBackup']],
    df['Churn'],
    normalize='index'
)*100
# Out:
# Churn                                           No        Yes
# OnlineSecurity      OnlineBackup
# No                  No                   51.845103  48.154897
#                     Yes                  68.994628  31.005372
# No internet service No internet service  92.595020   7.404980
# Yes                 No                   80.291153  19.708847
#                     Yes                  89.431616  10.568384

# %% [markdown]
# although customers with online backup may also subscribe to tech support but further analysis shows that even in different tech support group online backup is still associated with lower churn rates
# this suggests that online Backup provides stronger predictive information beyond tech support alone

# %%
catcols
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Churn'],
#       dtype='str')

# %%
#Online security done, online backup done tech support done, payment method done, contract type done, internet service done,

# %%
sns.countplot(x=df['MultipleLines'], hue=df['Churn'])
# Out:
# <Axes: xlabel='MultipleLines', ylabel='count'>

# %%
pd.crosstab(
    df['MultipleLines'],
    df['Churn'],
    normalize = 'index'
)*100
# Out:
# Churn                    No        Yes
# MultipleLines
# No                74.955752  25.044248
# No phone service  75.073314  24.926686
# Yes               71.390104  28.609896

# %%
sns.countplot(x=df['PhoneService'], hue=df['Churn'])
# Out:
# <Axes: xlabel='PhoneService', ylabel='count'>

# %%
pd.crosstab(
    df['PhoneService'],
    df['Churn'],
    normalize = 'index'
)*100
# Out:
# Churn                No        Yes
# PhoneService
# No            75.073314  24.926686
# Yes           73.290363  26.709637

# %% [markdown]
# Observations:
# the churn rates are similar in every category in phone service and multiple line feature so it seems that these feature doesn't really explain that much information in the churn

# %%
#Online security done, online backup done tech support done, payment method done, contract type done, internet service done, multiplelines, phoneservices

# %%
catcols
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Churn'],
#       dtype='str')

# %%
sns.countplot(x=df['DeviceProtection'], hue=df['Churn'])
# Out:
# <Axes: xlabel='DeviceProtection', ylabel='count'>

# %%
pd.crosstab(
    df['DeviceProtection'],
    df['Churn'],
    normalize = 'index'
)*100
# Out:
# Churn                       No        Yes
# DeviceProtection
# No                   60.872375  39.127625
# No internet service  92.595020   7.404980
# Yes                  77.497936  22.502064

# %% [markdown]
# Observations:
# it seems that having device protection is associated with lower churn rates creating a difference of 17% that is more than enough to continue investigating the feature

# %%
pd.crosstab(
    [df['Contract'],df['DeviceProtection']],
    df['Churn'],
    normalize = 'index'
)*100
# Out:
# Churn                                      No        Yes
# Contract       DeviceProtection
# Month-to-month No                   52.422723  47.577277
#                No internet service  81.106870  18.893130
#                Yes                  56.426332  43.573668
# One year       No                   86.393089  13.606911
#                No internet service  97.527473   2.472527
#                Yes                  85.448916  14.551084
# Two year       No                   96.218487   3.781513
#                No internet service  99.216301   0.783699
#                Yes                  95.848596   4.151404

# %% [markdown]
# among the different contract type having device protection creates a difference of only 3% from max and min values which is very low
# device protection doesn't explain the churn rates among different contract types

# %%
pd.crosstab(
    [df['InternetService'],df['DeviceProtection']],
    df['Churn'],
    normalize = 'index'
)*100
# Out:
# Churn                                       No        Yes
# InternetService DeviceProtection
# DSL             No                   74.778761  25.221239
#                 Yes                  89.014085  10.985915
# Fiber optic     No                   50.028752  49.971248
#                 Yes                  68.459838  31.540162
# No              No internet service  92.595020   7.404980

# %% [markdown]
# having device protection is associated with lower churn in each of the internet service categories reducing it by 19% in the fiber optic category

# %%
pd.crosstab(
    [df['TechSupport'],df['DeviceProtection']],
    df['Churn'],
    normalize = 'index'
)*100
# Out:
# Churn                                           No        Yes
# TechSupport         DeviceProtection
# No                  No                   53.628319  46.371681
#                     Yes                  67.188788  32.811212
# No internet service No internet service  92.595020   7.404980
# Yes                 No                   80.479042  19.520958
#                     Yes                  87.841191  12.158809

# %%
pd.crosstab(
    [df['OnlineSecurity'],df['DeviceProtection']],
    df['Churn'],
    normalize = 'index'
)*100
# Out:
# Churn                                           No        Yes
# OnlineSecurity      DeviceProtection
# No                  No                   52.949246  47.050754
#                     Yes                  67.048055  32.951945
# No internet service No internet service  92.595020   7.404980
# Yes                 No                   79.955947  20.044053
#                     Yes                  89.828983  10.171017

# %%
pd.crosstab(
    [df['OnlineBackup'],df['DeviceProtection']],
    df['Churn'],
    normalize = 'index'
)*100
# Out:
# Churn                                           No        Yes
# OnlineBackup        DeviceProtection
# No                  No                   54.082661  45.917339
#                     Yes                  70.833333  29.166667
# No internet service No internet service  92.595020   7.404980
# Yes                 No                   72.997300  27.002700
#                     Yes                  83.080425  16.919575

# %% [markdown]
# Device protection seems to be associated with lower churn rates in tech support, online security and online backup features creating a difference of almost 15% in each case

# %%
#Online security done, online backup done tech support done, payment method done, contract type done, internet service done, multiplelines, phoneservices, device protection

# %%
catcols
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Churn'],
#       dtype='str')

# %%
sns.countplot(x=df['PaperlessBilling'], hue=df['Churn'])
# Out:
# <Axes: xlabel='PaperlessBilling', ylabel='count'>

# %%
pd.crosstab(
    df['PaperlessBilling'],
    df['Churn'],
    normalize = 'index'
)*100
# Out:
# Churn                    No        Yes
# PaperlessBilling
# No                83.669916  16.330084
# Yes               66.434908  33.565092

# %% [markdown]
# Observation:
# papered billing shows lower churn rates with a difference of around 15%
# customers may prefer paper billing due to the concerns of missing important bills in the email
# additionally papered billing makes it easier to organize and review the bills because of the tangible nature
#
#
# Hypothesis:
# Is it possible that customers with no internet services choose papered billing on paperless
# Customers with longer tenure may choose to go for papered billing to manage and review old bills however the dataset does not provide enough data to test this hypothesis we may need feedback from customers for that
# customers of a shorter contract type may miss the bills from the email that might result in a churn

# %%
pd.crosstab(
    [df['Contract'],df['PaperlessBilling']],
    df['Churn'],
    normalize = 'index'
)*100
# Out:
# Churn                                   No        Yes
# Contract       PaperlessBilling
# Month-to-month No                68.502715  31.497285
#                Yes               51.701469  48.298531
# One year       No                92.867756   7.132244
#                Yes               85.250000  14.750000
# Two year       No                98.351648   1.648352
#                Yes               95.796178   4.203822

# %% [markdown]
# Through out all the contract types papered billing seems to have a lower churn rate than paperless billing that may explain out missing bill hypothesis

# %%
catcols
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Churn'],
#       dtype='str')

# %% [markdown]
# paperless billing can also be strongly correlated to payment method feature we need to check it

# %%
pd.crosstab(
    [df['PaymentMethod'],df['PaperlessBilling']],
    df['Churn'],
    normalize = 'index'
)*100
# Out:
# Churn                                              No        Yes
# PaymentMethod             PaperlessBilling
# Bank transfer (automatic) No                88.973966  11.026034
#                           Yes               79.124579  20.875421
# Credit card (automatic)   No                90.000000  10.000000
#                           Yes               80.952381  19.047619
# Electronic check          No                67.255217  32.744783
#                           Yes               50.229621  49.770379
# Mailed check              No                86.506276  13.493724
#                           Yes               72.713415  27.286585

# %% [markdown]
# Throughout all the payment methods the paperless billing seems to have lower churn rates with a difference of ~10%
# paperless billing appears to be a decent indicator of churn

# %%
#Online security done, online backup done tech support done, payment method done, contract type done, internet service done, multiplelines, phoneservices, device protection, paperless billing
#Bi variate analysis

# %% [markdown]
# multivariate analysis now

# %%
catcols
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'Churn'],
#       dtype='str')

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='str')

# %%
df['SeniorCitizen'] = df['SeniorCitizen'].astype('object')

# %%
#hypothesis for multivariate analysis

# %% [markdown]
# 1. short tenure customer on month to month contract at higher risks
# 2. short tenure customer with very high monthly charges at higher risk
# 3. customer with dependents sho
# 4.

# %%
sns.countplot(x=df['Dependents'], hue=df['Churn'])
# Out:
# <Axes: xlabel='Dependents', ylabel='count'>

# %%
pd.crosstab(
    [df['Contract'],df['Dependents']],
    df['Churn'],
    normalize='index'
)*100
# Out:
# Churn                             No        Yes
# Contract       Dependents
# Month-to-month No          54.763448  45.236552
#                Yes         67.173638  32.826362
# One year       No          87.579618  12.420382
#                Yes         90.772128   9.227872
# Two year       No          96.685083   3.314917
#                Yes         97.721519   2.278481

# %%
sns.boxplot(y=df['tenure'], x=df['Dependents'], hue=df['Churn'])
# Out:
# <Axes: xlabel='Dependents', ylabel='tenure'>

# %%
pd.crosstab(
    [df['InternetService'],df['OnlineSecurity']],
    df['Churn'],
    normalize='index'
)*100
# Out:
# Churn                                       No        Yes
# InternetService OnlineSecurity
# DSL             No                   72.038678  27.961322
#                 Yes                  90.508475   9.491525
# Fiber optic     No                   50.642446  49.357554
#                 Yes                  78.188319  21.811681
# No              No internet service  92.595020   7.404980

# %%
pd.crosstab(
    [df['InternetService'],df['OnlineBackup']],
    df['Churn'],
    normalize='index'
)*100
# Out:
# Churn                                       No        Yes
# InternetService OnlineBackup
# DSL             No                   74.307116  25.692884
#                 Yes                  89.318600  10.681400
# Fiber optic     No                   49.229892  50.770108
#                 Yes                  69.694713  30.305287
# No              No internet service  92.595020   7.404980

# %%
pd.crosstab(
    [df['InternetService'],df['TechSupport']],
    df['Churn'],
    normalize='index'
)*100
# Out:
# Churn                                       No        Yes
# InternetService TechSupport
# DSL             No                   72.244570  27.755430
#                 Yes                  90.322581   9.677419
# Fiber optic     No                   50.627803  49.372197
#                 Yes                  77.367206  22.632794
# No              No internet service  92.595020   7.404980

# %% [markdown]
# Among customers with InternetService, TechSupport, OnlineSecurity, and OnlineBackup are each associated with lower churn, and these associations persist within both DSL and Fiber Optic customers.

# %%
sns.scatterplot(
    x=df["tenure"],
    y=df["MonthlyCharges"],
    hue=df["Churn"]
)
# Out:
# <Axes: xlabel='tenure', ylabel='MonthlyCharges'>

# %%
df.groupby("Churn")[["tenure", "MonthlyCharges"]].corr()
# Out:
#                         tenure  MonthlyCharges
# Churn
# No    tenure          1.000000        0.330892
#       MonthlyCharges  0.330892        1.000000
# Yes   tenure          1.000000        0.401286
#       MonthlyCharges  0.401286        1.000000
